# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  
# %matplotlib inline
import pickle

#import keras
#from keras.layers import Activation, Dense, Conv1D, Conv2D, MaxPooling1D, Flatten, Reshape, Dropout
#from keras.models import Sequential

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import tensorflow_io as tfio

from sklearn.utils import shuffle
from sklearn.preprocessing import MultiLabelBinarizer, LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)
else:
    print('no gpu')

# %%
#features = pd.read_csv('data/features.csv', index_col=0, header=[0, 1, 2])
fma_single = pickle.load(open("saved/fma_single.p", "rb"))

# %%
fma_single
# Out:
#              split  subset                       filepath genre_top
# track_id
# 2         training   small  data/fma_large/000/000002.mp3   Hip-Hop
# 3         training  medium  data/fma_large/000/000003.mp3   Hip-Hop
# 5         training   small  data/fma_large/000/000005.mp3   Hip-Hop
# 10        training   small  data/fma_large/000/000010.mp3       Pop
# 134       training  medium  data/fma_large/000/000134.mp3   Hip-Hop
# ...            ...     ...                            ...       ...
# 155315    training   large  data/fma_large/155/155315.mp3      Rock
# 155316    training   large  data/fma_large/155/155316.mp3      Rock
# 155317    training   large  data/fma_large/155/155317.mp3      Rock
# 155318    training   large  data/fma_large/155/155318.mp3      Rock
# 155319    training   large  data/fma_large/155/155319.mp3      Rock
#
# [49537 rows x 4 columns]

# %% [markdown]
# For the baseline model we are going to use the 'small' set of 8000 tracks in 8 classes, and train the model on the mfccs of the tracks which we extracted earlier.

# %%
#load mfccs
mfcc_df=pickle.load(open("saved/mfcc_small.p","rb"))

# %%
mfcc_df.shape
# Out:
# (7997, 23232)

# %%
mfcc_df.head()
# Out:
#           0           1           2           3           4           5      \
# 2   -299.542053 -202.513412 -159.976059 -115.456413  -80.415161  -67.523239
# 5   -324.059723 -227.421249 -186.883606 -158.489868  -94.902466  -95.517578
# 10   -71.376122  -32.296730  -29.356266  -38.037708  -44.881695  -45.910717
# 140 -561.324280 -523.545837 -449.814423 -342.445557 -306.727356 -308.809631
# 141 -464.980743 -371.434326 -330.917175 -342.813904 -362.013550 -368.364441
#
#           6           7           8           9      ...     23222     23223  \
# 2    -57.689404  -65.464790  -84.703659  -96.179939  ... -5.861199 -4.460218
# 5   -106.146324  -70.498611  -45.091522  -41.156029  ... -6.403229 -4.675876
# 10   -31.081173    8.275231   28.077381    6.006516  ...  9.814901  0.409050
# 140 -307.733276 -317.345245 -362.774811 -419.306946  ...  1.818927  3.912658
# 141 -361.755188 -358.438049 -365.668640 -375.685730  ...  0.601643 -0.995060
#
#         23224      23225      23226      23227      23228     23229  \
# 2   -6.887738  -7.665272   6.717929  12.769140  11.439809  9.167293
# 5    5.932048  19.163589  24.138350  12.146925   1.931949 -0.370714
# 10  -6.546686  -4.728213  -2.329597   4.121199   8.337200  8.429386
# 140  4.593844   2.139801  -4.394735  -5.267244  -6.697974 -5.783470
# 141  0.146230   3.676285  -1.177926  -2.822582   4.884428  3.736303
#
#          23230      23231
# 2     7.916427   5.665779
# 5     1.137535  -0.625799
# 10   10.133602  11.033691
# 140  -5.886441  -3.706590
# 141   2.701882  -2.805002
#
# [5 rows x 23232 columns]

# %%
mfcc_df.replace([np.inf, -np.inf], np.nan)
# Out:
#              0           1           2           3           4      \
# 2      -299.542053 -202.513412 -159.976059 -115.456413  -80.415161
# 5      -324.059723 -227.421249 -186.883606 -158.489868  -94.902466
# 10      -71.376122  -32.296730  -29.356266  -38.037708  -44.881695
# 140    -561.324280 -523.545837 -449.814423 -342.445557 -306.727356
# 141    -464.980743 -371.434326 -330.917175 -342.813904 -362.013550
# ...            ...         ...         ...         ...         ...
# 154308 -313.429077 -285.330048 -283.423401 -287.088348 -289.263672
# 154309 -486.301819 -482.713928 -496.109802 -501.279755 -502.606598
# 154413 -155.809250 -137.494919 -114.974205 -140.923645 -162.126450
# 154414 -157.556030 -162.392120 -172.492035 -185.008377 -195.222931
# 155066 -239.451935 -245.493454 -252.646561 -198.174835 -176.131500
#
#              5           6           7           8           9      ...  \
# 2       -67.523239  -57.689404  -65.464790  -84.703659  -96.179939  ...
# 5       -95.517578 -106.146324  -70.498611  -45.091522  -41.156029  ...
# 10      -45.910717  -31.081173    8.275231   28.077381    6.006516  ...
# 140    -308.809631 -307.733276 -317.345245 -362.774811 -419.306946  ...
# 141    -368.364441 -361.755188 -358.438049 -365.668640 -375.685730  ...
# ...            ...         ...         ...         ...         ...  ...
# 154308 -184.150192  -41.746201  -12.892635  -55.076210 -115.045479  ...
# 154309 -506.784668 -509.464905 -310.994598 -145.997116 -127.237030  ...
# 154413 -160.300812 -160.252792 -164.502640 -163.036118 -166.671722  ...
# 154414 -197.421844 -194.316422 -151.761810  -53.744122    0.694292  ...
# 155066 -206.888504 -248.449234 -260.804413 -262.628052 -267.949860  ...
#
#             23222      23223      23224      23225      23226      23227  \
# 2       -5.861199  -4.460218  -6.887738  -7.665272   6.717929  12.769140
# 5       -6.403229  -4.675876   5.932048  19.163589  24.138350  12.146925
# 10       9.814901   0.409050  -6.546686  -4.728213  -2.329597   4.121199
# 140      1.818927   3.912658   4.593844   2.139801  -4.394735  -5.267244
# 141      0.601643  -0.995060   0.146230   3.676285  -1.177926  -2.822582
# ...           ...        ...        ...        ...        ...        ...
# 154308  10.231204  11.211655   0.058539 -11.264427  -6.596434   4.120525
# 154309  -3.249464 -10.734337 -11.473764  -8.660153  -7.335606 -11.601185
# 154413 -16.811752 -17.902248 -22.706905 -22.197693 -24.581553 -25.488754
# 154414 -14.949778 -13.652007 -14.656978 -12.779702 -15.503021 -17.758909
# 155066   8.492558   7.201674   8.079520  15.428879  19.309864  18.128532
#
#             23228      23229      23230      23231
# 2       11.439809   9.167293   7.916427   5.665779
# 5        1.931949  -0.370714   1.137535  -0.625799
# 10       8.337200   8.429386  10.133602  11.033691
# 140     -6.697974  -5.783470  -5.886441  -3.706590
# 141      4.884428   3.736303   2.701882  -2.805002
# ...           ...        ...        ...        ...
# 154308   6.856134   5.343898   2.773130   1.698187
# 154309 -16.454685 -15.517137 -11.830728 -11.240954
# 154413 -21.233810 -23.033970 -21.506649 -22.316118
# 154414 -18.673512 -14.957970 -11.633366 -14.272188
# 155066   8.843944   6.262315   9.994928  12.015592
#
# [7997 rows x 23232 columns]

# %%
mfcc_df.fillna(method='ffill',inplace=True)

# %%
#use the 8000 track balanced subset for baseline modeling

drop3=pickle.load(open("saved/drop3.p","rb"))
fma_single.drop(drop3, inplace=True)

# %%
subset = fma_single.index[fma_single['subset'] == 'small']

# %%
fma_small=fma_single.loc[subset]

# %%
mfcc_sub=mfcc_df.loc[subset]

# %%
#use the built in train/test/validation split in case we want to compare to other models over this dataset
train = fma_small.index[fma_small['split'] == 'training']
val = fma_small.index[fma_small['split'] == 'validation']
test = fma_small.index[fma_small['split'] == 'test']

# %%
print(len(train),len(val),len(test))
# Out:
# 6310 793 794

# %%
#preprocessing single label

#enc=MultiLabelBinarizer()
enc=LabelEncoder()
labels=fma_small['genre_top']
#labels=y_df

# Split in training, validation and testing sets.

#single label
y_train = enc.fit_transform(labels[train])
y_val = enc.transform(labels[val])
y_test = enc.transform(labels[test])
#y_train = track_sub['label']

X_train = mfcc_sub.loc[train].values
X_val = mfcc_sub.loc[val].values
X_test = mfcc_sub.loc[test].values
    
X_train, y_train = shuffle(X_train, y_train, random_state=42)

# %%
# Standardize features
scaler = StandardScaler(copy=False)
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (6310, 23232)

# %%
keras.backend.clear_session()

model = models.Sequential()

model.add(layers.Reshape((726,32),input_shape=(X_train.shape[1],)))
model.add(layers.Conv1D(64, 3, activation='relu'))
model.add(layers.MaxPooling1D(2))
model.add(layers.Conv1D(128, 3, activation='relu'))
model.add(layers.MaxPooling1D(2))
model.add(layers.Conv1D(128, 3, activation='relu'))
model.add(layers.MaxPooling1D(2))
model.add(layers.Dropout(.2))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(.2))
model.add(layers.Dense(8, activation='softmax'))

loss=tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=True)
model.compile(optimizer=optimizer,
              loss=loss,
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 726, 32)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 724, 64)           6208
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 362, 64)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 360, 128)          24704
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 180, 128)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 178, 128)          49280
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 89, 128)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 89, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 11392)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1458304
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 1,539,528
# Trainable params: 1,539,528
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
with tf.device('/GPU:0'):
    history=model.fit(X_train,
              y_train,
              epochs=40,
              batch_size=32,
              validation_data=(X_val, y_val))
# Out:
# Epoch 1/40
# 198/198 [==============================] - 1s 7ms/step - loss: 2.0427 - accuracy: 0.1929 - val_loss: 1.8891 - val_accuracy: 0.2812
# Epoch 2/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.8382 - accuracy: 0.3151 - val_loss: 1.7509 - val_accuracy: 0.3707
# Epoch 3/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.7282 - accuracy: 0.3667 - val_loss: 1.6787 - val_accuracy: 0.3934
# Epoch 4/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.6673 - accuracy: 0.4030 - val_loss: 1.6337 - val_accuracy: 0.4149
# Epoch 5/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.6283 - accuracy: 0.4133 - val_loss: 1.6154 - val_accuracy: 0.4098
# Epoch 6/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.5928 - accuracy: 0.4242 - val_loss: 1.5965 - val_accuracy: 0.4388
# Epoch 7/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.5707 - accuracy: 0.4390 - val_loss: 1.5868 - val_accuracy: 0.4338
# Epoch 8/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.5556 - accuracy: 0.4472 - val_loss: 1.5822 - val_accuracy: 0.4174
# Epoch 9/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.5386 - accuracy: 0.4563 - val_loss: 1.5724 - val_accuracy: 0.4224
# Epoch 10/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.5221 - accuracy: 0.4566 - val_loss: 1.5745 - val_accuracy: 0.4275
# Epoch 11/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.4980 - accuracy: 0.4683 - val_loss: 1.5661 - val_accuracy: 0.4275
# Epoch 12/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.4798 - accuracy: 0.4727 - val_loss: 1.5597 - val_accuracy: 0.4250
# Epoch 13/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.4600 - accuracy: 0.4818 - val_loss: 1.5654 - val_accuracy: 0.4237
# Epoch 14/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.4463 - accuracy: 0.4943 - val_loss: 1.5576 - val_accuracy: 0.4351
# Epoch 15/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.4293 - accuracy: 0.4943 - val_loss: 1.5509 - val_accuracy: 0.4388
# Epoch 16/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.4134 - accuracy: 0.5000 - val_loss: 1.5624 - val_accuracy: 0.4224
# Epoch 17/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.4027 - accuracy: 0.5059 - val_loss: 1.5464 - val_accuracy: 0.4300
# Epoch 18/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.3842 - accuracy: 0.5149 - val_loss: 1.5478 - val_accuracy: 0.4250
# Epoch 19/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.3654 - accuracy: 0.5181 - val_loss: 1.5436 - val_accuracy: 0.4388
# Epoch 20/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.3499 - accuracy: 0.5273 - val_loss: 1.5522 - val_accuracy: 0.4187
# Epoch 21/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.3431 - accuracy: 0.5355 - val_loss: 1.5403 - val_accuracy: 0.4414
# Epoch 22/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.3350 - accuracy: 0.5326 - val_loss: 1.5529 - val_accuracy: 0.4224
# Epoch 23/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.3122 - accuracy: 0.5357 - val_loss: 1.5427 - val_accuracy: 0.4401
# Epoch 24/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.2966 - accuracy: 0.5510 - val_loss: 1.5412 - val_accuracy: 0.4376
# Epoch 25/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.2840 - accuracy: 0.5567 - val_loss: 1.5415 - val_accuracy: 0.4426
# Epoch 26/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.2776 - accuracy: 0.5520 - val_loss: 1.5418 - val_accuracy: 0.4351
# Epoch 27/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.2582 - accuracy: 0.5624 - val_loss: 1.5322 - val_accuracy: 0.4451
# Epoch 28/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.2404 - accuracy: 0.5735 - val_loss: 1.5425 - val_accuracy: 0.4325
# Epoch 29/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.2307 - accuracy: 0.5829 - val_loss: 1.5499 - val_accuracy: 0.4351
# Epoch 30/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.2166 - accuracy: 0.5808 - val_loss: 1.5480 - val_accuracy: 0.4325
# Epoch 31/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.2059 - accuracy: 0.5880 - val_loss: 1.5502 - val_accuracy: 0.4414
# Epoch 32/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.1984 - accuracy: 0.5846 - val_loss: 1.5328 - val_accuracy: 0.4464
# Epoch 33/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.1876 - accuracy: 0.5878 - val_loss: 1.5413 - val_accuracy: 0.4426
# Epoch 34/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.1655 - accuracy: 0.6086 - val_loss: 1.5381 - val_accuracy: 0.4414
# Epoch 35/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.1650 - accuracy: 0.6071 - val_loss: 1.5462 - val_accuracy: 0.4515
# Epoch 36/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.1522 - accuracy: 0.6062 - val_loss: 1.5397 - val_accuracy: 0.4388
# Epoch 37/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.1325 - accuracy: 0.6197 - val_loss: 1.5392 - val_accuracy: 0.4363
# Epoch 38/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.1261 - accuracy: 0.6197 - val_loss: 1.5418 - val_accuracy: 0.4489
# Epoch 39/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.1106 - accuracy: 0.6265 - val_loss: 1.5487 - val_accuracy: 0.4502
# Epoch 40/40
# 198/198 [==============================] - 1s 6ms/step - loss: 1.0951 - accuracy: 0.6393 - val_loss: 1.5433 - val_accuracy: 0.4388
# CPU times: user 1min 19s, sys: 4.82 s, total: 1min 24s
# Wall time: 51 s

# %%
plt.figure(figsize=(15,7))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that the accuracy and loss over the validation set diverge from the test set once the model achieves about 45% accuracy on the validation set.

# %%
y_pred=model.predict_classes(X_test)
print('Classification Report (test set)')
print(classification_report(y_test,y_pred))
# Out:
# WARNING:tensorflow:From <ipython-input-22-40390394529f>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Classification Report (test set)
#               precision    recall  f1-score   support
#
#            0       0.46      0.54      0.50        96
#            1       0.15      0.13      0.14        98
#            2       0.18      0.19      0.18       100
#            3       0.64      0.69      0.66       100
#            4       0.28      0.21      0.24       100
#            5       0.40      0.51      0.45       100
#            6       0.30      0.26      0.28       100
#            7       0.58      0.52      0.55       100
#
#     accuracy                           0.38       794
#    macro avg       0.37      0.38      0.38       794
# weighted avg       0.37      0.38      0.38       794

# %% [markdown]
# Over the set of:
# * 8 classes
# * 1000 samples each class
#
# The Convolutional Neural Network shows an improvement over the baseline.

# %% [markdown]
# | Model | Accuracy(all classes) | Train Time |
# | --- | --- | --- |
# | Baseline | .30 | 5m |
# | CNN | .40 | 1m |
