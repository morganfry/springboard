# %% [markdown]
# ## Springboard Data Science Track Capstone Project 1
# ### Histopathologic Cancer Detection
# ### by Morgan Fry
# ### Data Exploration notebook

# %% [markdown]
# #### We are examining images of slides of lymph tissue samples treated with contrast in order to detect cancer cells. This notebook will look at these images as data and see what we can tell

# %%
#includes
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  
# %matplotlib inline

from matplotlib.image import imread
import cv2    

from sklearn.utils import shuffle
import pickle
import sys
import seaborn as sns

# %%
#load data saved in data wrangling notebook
y=pickle.load(open("saved/y.p","rb"))
X=pickle.load(open("saved/X.p","rb"))
X_vect=pickle.load(open("saved/X_vect.p","rb"))
#X_gray=pickle.load(open("saved/X_gray.p","rb"))
#X_gray_vect=pickle.load(open("saved/X_gra_vect.p","rb"))

# %% [markdown]
# ##### Let's look at a few of the samples, in color and in grayscale

# %%
#select 8 at random
shuffled_y=shuffle(y)

fig,ax = plt.subplots(4,4, figsize=(20,24))

#4 negatives
for i, idx in enumerate(shuffled_y[shuffled_y['label'] == 0]['id'][:4]):
    ax[0,i].imshow(X.get(idx))
    ax[0,i].set_title('Negative')
    
#4 negatives grayscale
#for i, idx in enumerate(shuffled_y[shuffled_y['label'] == 0]['id'][:4]):
#    ax[1,i].imshow(X_gray.get(idx), cmap='gray')
#    ax[1,i].set_title('Negative')
    
#4 positives
for i, idx in enumerate(shuffled_y[shuffled_y['label'] == 1]['id'][:4]):
    ax[2,i].imshow(X.get(idx))
    ax[2,i].set_title('Positive')
    

#4 positives grayscale
#for i, idx in enumerate(shuffled_y[shuffled_y['label'] == 1]['id'][:4]):
#    ax[3,i].imshow(X_gray.get(idx), cmap='gray')
#    ax[3,i].set_title('Positive')

# %% [markdown]
# ##### To begin looking for trends in the data, first we'll split into positive and negative groups in advance of plotting some features

# %%
y_pos=y[y.label == 1]
y_neg=y[y.label == 0]

# %%
X_pos=X.copy()
X_pos_vect=X_vect.copy()
#X_pos_gray=X_gray.copy()
for idx,row in y_neg.iterrows():
    X_pos.pop(row['id'])
    #X_pos_gray.pop(row['id'])
    X_pos_vect.pop(row['id'])

X_neg=X.copy()
#X_neg_gray=X_gray.copy()
X_neg_vect=X_vect.copy()
for idx,row in y_pos.iterrows():
    X_neg.pop(row['id'])
    #X_neg_gray.pop(row['id'])
    X_neg_vect.pop(row['id'])

# %%
samples=[len(X_pos),len(X_neg)]

fig = plt.figure(figsize=(4, 2),dpi=100)
plt.bar([1,0], [len(X_neg),len(X_pos)])
plt.xticks([1,0],["Negative ({})".format(len(X_neg)),"Positive ({})".format(len(X_pos))])
plt.title("Number of samples")
plt.show()

# %% [markdown]
# ##### First of all, we can notice that the training data contains about 60% negative and 40% positive samples.

# %% [markdown]
# The dataset is made up of images, so a few ways of exploring the data come to mind:
# * intensity of each of the color channels
# * aggregations of the channels

# %%
X_pos_l=list(X_pos.values())
X_neg_l=list(X_neg.values())
X_pos_vect_l=list(X_pos_vect.values())
X_neg_vect_l=list(X_neg_vect.values())

# %%
fig,axs = plt.subplots(1,2,sharey=True,figsize=(12,5))

sns.distplot(X_pos_l[:][:][:][0].flatten(),hist=False,color='blue',label='blue',ax=axs[0]).set_title('Positive')
sns.distplot(X_pos_l[:][:][:][1].flatten(),hist=False,color='green',label='green',ax=axs[0]).set_xlabel('pixel value')
sns.distplot(X_pos_l[:][:][:][2].flatten(),hist=False,color='red',label='red',ax=axs[0]).set_ylabel('relative frequency')
sns.distplot(X_neg_l[:][:][:][0].flatten(),hist=False,color='blue',label='blue',ax=axs[1]).set_title('Negative')
sns.distplot(X_neg_l[:][:][:][1].flatten(),hist=False,color='green',label='green',ax=axs[1]).set_xlabel('pixel value')
sns.distplot(X_neg_l[:][:][:][2].flatten(),hist=False,color='red',label='red',ax=axs[1])

plt.figtext(.3,0,'The relative frequencies of the color channel values.',fontsize='large')
plt.show()

# %% [markdown]
# There appears to be some differences between the positive and negative sets, so let's compare the individual color channels individually to see if anything sticks out.

# %%
fig,axs = plt.subplots(3,1,figsize=(8,20))

sns.distplot(X_pos_l[:][:][:][0].flatten(),hist=False,label='Positive',ax=axs[0]).set_title('Blue')
sns.distplot(X_neg_l[:][:][:][0].flatten(),hist=False,label='Negative',ax=axs[0])
sns.distplot(X_pos_l[:][:][:][1].flatten(),hist=False,label='Positive',ax=axs[1]).set_title('Green')
sns.distplot(X_neg_l[:][:][:][1].flatten(),hist=False,label='Negative',ax=axs[1])
sns.distplot(X_pos_l[:][:][:][1].flatten(),hist=False,label='Positive',ax=axs[2]).set_title('Red')
sns.distplot(X_neg_l[:][:][:][1].flatten(),hist=False,label='Negative',ax=axs[2])

plt.show()

# %% [markdown]
# #### We can begin to see a difference in the distribution of color between positive and negative samples. Among the Positive group we see:
# * The blue channel is muted
# * The red and green channels are shifted left, indicating less of those colors in the positive samples
#
# #### Next we will examine the results of some aggregation to see if there is anything we can learn there.

# %%
#X_pos_gray_l=list(X_pos_gray.values())
#X_neg_gray_l=list(X_neg_gray.values())
#X_pos_gray_l=[np.ravel(each) for each in X_pos_gray_l]
#X_neg_gray_l=[np.ravel(each) for each in X_neg_gray_l]

# %%
#X_pos_gray_np=np.asarray(X_pos_gray_l)
#X_neg_gray_np=np.asarray(X_neg_gray_l)

# %%
#create some aggregates of the data
X_pos_mean=[np.mean(each) for each in X_pos_vect_l]
X_neg_mean=[np.mean(each) for each in X_neg_vect_l]
X_pos_med=[np.median(each) for each in X_pos_vect_l]
X_neg_med=[np.median(each) for each in X_neg_vect_l]

# %%
fig,axs = plt.subplots(1,2, sharey=True, figsize=(18,8))

sns.distplot(X_pos_mean,hist=False,label='Positive',ax=axs[0]).set_title('Mean')
sns.distplot(X_neg_mean,hist=False,label='Negative',ax=axs[0])
sns.distplot(X_pos_med,hist=False,label='Positive',ax=axs[1]).set_title('Median')
sns.distplot(X_neg_med,hist=False,label='Negative',ax=axs[1])

plt.show()

# %% [markdown]
# ###### There is a clear difference in the distribution of the mean values of the positive and negative sets.

# %% [markdown]
# Given the dfference in distribution between both the mean and median values of the images, it may be informative to see if ano one channel is particularly responsible. So let's look at similar aggregations for the individual color channels

# %%
#first isolating the aggregations makes it a little simpler to deal with
X_pos_grn=X_pos_l[:][:][:][1]
X_pos_grn_mean=[np.mean(np.ravel(each)) for each in X_pos_grn]
X_pos_blu=X_pos_l[:][:][:][0]
X_pos_blu_mean=[np.mean(np.ravel(each)) for each in X_pos_blu]
X_pos_red=X_pos_l[:][:][:][2]
X_pos_red_mean=[np.mean(np.ravel(each)) for each in X_pos_red]
X_neg_grn=X_neg_l[:][:][:][1]
X_neg_grn_mean=[np.mean(np.ravel(each)) for each in X_neg_grn]
X_neg_blu=X_neg_l[:][:][:][0]
X_neg_blu_mean=[np.mean(np.ravel(each)) for each in X_neg_blu]
X_neg_red=X_neg_l[:][:][:][2]
X_neg_red_mean=[np.mean(np.ravel(each)) for each in X_neg_red]

# %%
X_pos_grn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-c7221e35af1f> in <module>
# ----> 1 size(X_pos_grn)
#
# NameError: name 'size' is not defined

# %%
X_pos_grn_med=[np.median(np.ravel(each)) for each in X_pos_grn]
X_pos_blu_med=[np.median(np.ravel(each)) for each in X_pos_blu]
X_pos_red_med=[np.median(np.ravel(each)) for each in X_pos_red]
X_neg_grn_med=[np.median(np.ravel(each)) for each in X_neg_grn]
X_neg_blu_med=[np.median(np.ravel(each)) for each in X_neg_blu]
X_neg_red_med=[np.median(np.ravel(each)) for each in X_neg_red]

# %%
fig,axs = plt.subplots(3,2, sharey=True, sharex=True,figsize=(14,16))

sns.distplot(X_pos_grn_mean,hist=False,label='Positive',ax=axs[1,0]).set_title('Mean')
sns.distplot(X_neg_grn_mean,hist=False,label='Negative',ax=axs[1,0])
sns.distplot(X_pos_grn_mean,hist=False,label='Positive',ax=axs[1,1]).set_title('Median')
sns.distplot(X_neg_grn_mean,hist=False,label='Negative',ax=axs[1,1]).set_ylabel("Green",rotation='horizontal',labelpad=35)
sns.distplot(X_pos_red_mean,hist=False,label='Positive',ax=axs[2,0]).set_title('Mean')
sns.distplot(X_neg_red_mean,hist=False,label='Negative',ax=axs[2,0])
sns.distplot(X_pos_red_mean,hist=False,label='Positive',ax=axs[2,1]).set_title('Median')
sns.distplot(X_neg_red_mean,hist=False,label='Negative',ax=axs[2,1]).set_ylabel("Red",rotation='horizontal',labelpad=35)
sns.distplot(X_pos_blu_mean,hist=False,label='Positive',ax=axs[0,0]).set_title('Mean')
sns.distplot(X_neg_blu_mean,hist=False,label='Negative',ax=axs[0,0])
sns.distplot(X_pos_blu_mean,hist=False,label='Positive',ax=axs[0,1]).set_title('Median')
sns.distplot(X_neg_blu_mean,hist=False,label='Negative',ax=axs[0,1]).set_ylabel("Blue",rotation='horizontal',labelpad=35)

plt.show()

# %% [markdown]
# There is a pretty significant difference in especially the mean over the red channel between the positive and negative groups.

# %% [markdown]
# #### Truncating the data
# This dataset comes from the PatchCamelyon set with duplicates removed, and according a positive  sample is defined as the center 32x32 pixel region containing at least 1 pixel of tumor tissue. As such, it may be interesting to see if the data from just this region tellsa different or clearer story than the data as a whole.

# %%
#first task is to crop the images.
#function to crop to the middle of these images
#returns dictionary
def crop_img(Xl):
    X_t={}
    for k,v in Xl.items():
        X_t[k]=v[32:63,32:63]
    return(X_t)

# %%
X_c=crop_img(X)
X_c_pos=crop_img(X_pos)
X_c_neg=crop_img(X_neg)

# %%
#then repeat a few of the plots and compare
X_c_pos_l=list(X_c_pos.values())
X_c_neg_l=list(X_c_neg.values())

# %%
fig,axs = plt.subplots(2,2,sharey=True,figsize=(12,12))

sns.distplot(X_c_pos_l[:][:][:][0].flatten(),hist=False,color='blue',label='blue',ax=axs[0,0]).set_title('Positive')
sns.distplot(X_c_pos_l[:][:][:][1].flatten(),hist=False,color='green',label='green',ax=axs[0,0]).set_xlabel('pixel value')
sns.distplot(X_c_pos_l[:][:][:][2].flatten(),hist=False,color='red',label='red',ax=axs[0,0]).set_ylabel('relative frequency')
sns.distplot(X_c_neg_l[:][:][:][0].flatten(),hist=False,color='blue',label='blue',ax=axs[0,1]).set_title('Negative')
sns.distplot(X_c_neg_l[:][:][:][1].flatten(),hist=False,color='green',label='green',ax=axs[0,1]).set_xlabel('pixel value')
sns.distplot(X_c_neg_l[:][:][:][2].flatten(),hist=False,color='red',label='red',ax=axs[0,1])

sns.distplot(X_pos_l[:][:][:][0].flatten(),hist=False,color='blue',label='blue',ax=axs[1,0]).set_title('Positive')
sns.distplot(X_pos_l[:][:][:][1].flatten(),hist=False,color='green',label='green',ax=axs[1,0]).set_xlabel('pixel value')
sns.distplot(X_pos_l[:][:][:][2].flatten(),hist=False,color='red',label='red',ax=axs[1,0]).set_ylabel('relative frequency')
sns.distplot(X_neg_l[:][:][:][0].flatten(),hist=False,color='blue',label='blue',ax=axs[1,1]).set_title('Negative')
sns.distplot(X_neg_l[:][:][:][1].flatten(),hist=False,color='green',label='green',ax=axs[1,1]).set_xlabel('pixel value')
sns.distplot(X_neg_l[:][:][:][2].flatten(),hist=False,color='red',label='red',ax=axs[1,1])

plt.figtext(.3,0,'The relative frequencies of the color channel values.',fontsize='large')
plt.figtext(.4,1,'Cropped images on top',fontsize='large')
plt.show()

# %%
#individual channels
fig,axs = plt.subplots(3,2,figsize=(14,12))

sns.distplot(X_pos_l[:][:][:][0].flatten(),hist=False,label='Positive',ax=axs[0,0]).set_title('Blue')
sns.distplot(X_neg_l[:][:][:][0].flatten(),hist=False,label='Negative',ax=axs[0,1])
sns.distplot(X_pos_l[:][:][:][1].flatten(),hist=False,label='Positive',ax=axs[1,0]).set_title('Green')
sns.distplot(X_neg_l[:][:][:][1].flatten(),hist=False,label='Negative',ax=axs[1,1])
sns.distplot(X_pos_l[:][:][:][1].flatten(),hist=False,label='Positive',ax=axs[2,0]).set_title('Red')
sns.distplot(X_neg_l[:][:][:][1].flatten(),hist=False,label='Negative',ax=axs[2,1])

sns.distplot(X_c_pos_l[:][:][:][0].flatten(),hist=False,label='Cropped Positive',ax=axs[0,0])
sns.distplot(X_c_neg_l[:][:][:][0].flatten(),hist=False,label='Cropped Negative',ax=axs[0,1])
sns.distplot(X_c_pos_l[:][:][:][1].flatten(),hist=False,label='Cropped Positive',ax=axs[1,0])
sns.distplot(X_c_neg_l[:][:][:][1].flatten(),hist=False,label='Cropped Negative',ax=axs[1,1])
sns.distplot(X_c_pos_l[:][:][:][1].flatten(),hist=False,label='Cropped Positive',ax=axs[2,0])
sns.distplot(X_c_neg_l[:][:][:][1].flatten(),hist=False,label='Cropped Negative',ax=axs[2,1])


plt.show()

# %% [markdown]
# In all cases, the cropped images have a slightly tighter distribution.

# %%
#create some aggregates of the data

X_c_pos_mean=[np.mean(np.ravel(each)) for each in X_c_pos_l]
X_c_neg_mean=[np.mean(np.ravel(each)) for each in X_c_neg_l]
X_c_pos_med=[np.median(np.ravel(each)) for each in X_c_pos_l]
X_c_neg_med=[np.median(np.ravel(each)) for each in X_c_neg_l]

# %%
fig,axs = plt.subplots(2,2, sharey=True, figsize=(12,16))

sns.distplot(X_pos_mean,hist=False,label='Positive',ax=axs[0,0]).set_title('Mean')
sns.distplot(X_c_pos_mean,hist=False,label='Cropped Positive',ax=axs[0,0])
sns.distplot(X_pos_med,hist=False,label='Positive',ax=axs[0,1]).set_title('Median')
sns.distplot(X_c_pos_med,hist=False,label='Cropped Positive',ax=axs[0,1])

sns.distplot(X_neg_mean,hist=False,label='Negative',ax=axs[1,0]).set_title('Mean')
sns.distplot(X_c_neg_mean,hist=False,label='Cropped Negative',ax=axs[1,0])
sns.distplot(X_neg_med,hist=False,label='Negative',ax=axs[1,1]).set_title('Median')
sns.distplot(X_c_neg_med,hist=False,label='Cropped Negative',ax=axs[1,1])

plt.show()

# %% [markdown]
# Aggregate values so far don't show much consistent difference between using the entire images and the cener square.

# %%
#first isolating the aggregations makes it a little simpler to deal with

#################### this aint right at all ####################
X_c_pos_grn=X_c_pos_l[:][:][:][1]
X_c_pos_grn_mean=[np.mean(np.ravel(each)) for each in X_c_pos_grn]
X_c_pos_blu=X_c_pos_l[:][:][:][0]
X_c_pos_blu_mean=[np.mean(np.ravel(each)) for each in X_c_pos_blu]
X_c_pos_red=X_c_pos_l[:][:][:][2]
X_c_pos_red_mean=[np.mean(np.ravel(each)) for each in X_c_pos_red]
X_c_neg_grn=X_c_neg_l[:][:][:][1]
X_c_neg_grn_mean=[np.mean(np.ravel(each)) for each in X_c_neg_grn]
X_c_neg_blu=X_c_neg_l[:][:][:][0]
X_c_neg_blu_mean=[np.mean(np.ravel(each)) for each in X_c_neg_blu]
X_c_neg_red=X_c_neg_l[:][:][:][2]
X_c_neg_red_mean=[np.mean(np.ravel(each)) for each in X_c_neg_red]

# %%
len(X_c_pos_blu_mean)
# Out:
# 31

# %%
fig,axs = plt.subplots(3,2, sharey=True, sharex=True,figsize=(14,16))

sns.distplot(X_pos_grn_mean,hist=False,label='Original',ax=axs[1,0]).set_title('Mean(Positive)')
sns.distplot(X_c_pos_grn_mean,hist=False,label='Cropped',ax=axs[1,0])
sns.distplot(X_neg_grn_mean,hist=False,label='Original',ax=axs[1,1]).set_title('Mean(Negative)')
sns.distplot(X_c_neg_grn_mean,hist=False,label='Cropped',ax=axs[1,1]).set_ylabel("Green",rotation='horizontal',labelpad=35)
sns.distplot(X_pos_red_mean,hist=False,label='Original',ax=axs[2,0]).set_title('Mean(Positive)')
sns.distplot(X_c_pos_red_mean,hist=False,label='Cropped',ax=axs[2,0])
sns.distplot(X_neg_red_mean,hist=False,label='Original',ax=axs[2,1]).set_title('Mean(Negative)')
sns.distplot(X_c_neg_red_mean,hist=False,label='Cropped',ax=axs[2,1]).set_ylabel("Red",rotation='horizontal',labelpad=35)
sns.distplot(X_pos_blu_mean,hist=False,label='Original',ax=axs[0,0]).set_title('Mean(Positive)')
sns.distplot(X_c_pos_blu_mean,hist=False,label='Cropped',ax=axs[0,0])
sns.distplot(X_neg_blu_mean,hist=False,label='Original',ax=axs[0,1]).set_title('Mean(Negative)')
sns.distplot(X_c_neg_blu_mean,hist=False,label='Cropped',ax=axs[0,1]).set_ylabel("Blue",rotation='horizontal',labelpad=35)

plt.show()
